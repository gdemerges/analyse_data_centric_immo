# %%
import pandas as pd

df = pd.read_csv('valeursfoncieres-2022.txt', delimiter='|')

pd.set_option('display.max_columns', 43)
df
# Out:
# /var/folders/rt/0hb6rtq14291d__lx9m1jbd00000gn/T/ipykernel_9092/4021289028.py:3: DtypeWarning: Columns (18,23,24,26,28,29,31,33,41) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('valeursfoncieres-2022.txt', delimiter='|')
#          Identifiant de document  Reference document  1 Articles CGI  \
# 0                            NaN                 NaN             NaN
# 1                            NaN                 NaN             NaN
# 2                            NaN                 NaN             NaN
# 3                            NaN                 NaN             NaN
# 4                            NaN                 NaN             NaN
# ...                          ...                 ...             ...
# 4617585                      NaN                 NaN             NaN
# 4617586                      NaN                 NaN             NaN
# 4617587                      NaN                 NaN             NaN
# ...

# %%
toutes_valeurs_nan = df['Nature culture speciale'].isna().all()

print(toutes_valeurs_nan)
# Out:
# False

# %%
df_sans_colonnes_nan = df.dropna(axis=1, how='all')
df_sans_colonnes_nan
# Out:
#          No disposition Date mutation Nature mutation Valeur fonciere  \
# 0                     1    03/01/2022           Vente        55000,00
# 1                     1    03/01/2022           Vente       143000,00
# 2                     1    03/01/2022           Vente       143000,00
# 3                     1    03/01/2022           Vente       143000,00
# 4                     1    04/01/2022           Vente          300,00
# ...                 ...           ...             ...             ...
# 4617585               1    10/11/2022    Adjudication       188100,00
# 4617586               1    10/11/2022    Adjudication      2145000,00
# 4617587               1    10/11/2022    Adjudication      2145000,00
# 4617588               1    14/12/2022           Vente       111000,00
# 4617589               1    05/11/2022           Vente       366440,00
#
#          No voie B/T/Q Type de voie Code voie           Voie  Code postal  \
# ...
